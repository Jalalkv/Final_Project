# %%
#import libraries 
import pandas as pd
import numpy as np

# %% [markdown]
# ### 01 - Getting Data
# - in this research we will use three different datasets: two (for Nitrogen Dioxide and Particles Matter levels) of them for London and one for Paris air quality. So, lets import them

# %%
# import London Nitrogen Dioxide (NO2) dataset 
londonno2 = pd.read_csv('/Users/Lenovo/Desktop/NO2_full_network_20190101_20191231.csv')

# %%
londonno2.head()
# Out:
#                date_UTC  no2_ugm3  pod_id_location  pod_id location_name  \
# 0  2019-02-15T17:00:00Z     61.99             1245    1245   Dollis Road
# 1  2019-02-15T18:00:00Z     67.33             1245    1245   Dollis Road
# 2  2019-02-15T19:00:00Z     72.61             1245    1245   Dollis Road
# 3  2019-02-15T20:00:00Z     67.24             1245    1245   Dollis Road
# 4  2019-02-15T21:00:00Z     59.78             1245    1245   Dollis Road
#
#   ratification_status
# 0                   P
# 1                   P
# 2                   P
# 3                   P
# 4                   P

# %%
# get London Particles Matter 2.5 (PM2.5) data 
londonpm25 = pd.read_csv('/Users/Lenovo/Desktop/PM2.5_full_network_20190101_20191231.csv')

# %%
londonpm25.head()
# Out:
#                date_UTC  pm2_5_ugm3  pod_id_location  pod_id location_name  \
# 0  2019-02-15T13:00:00Z       20.17             1245    1245   Dollis Road
# 1  2019-02-15T14:00:00Z       18.47             1245    1245   Dollis Road
# 2  2019-02-15T15:00:00Z       19.84             1245    1245   Dollis Road
# 3  2019-02-15T16:00:00Z       36.68             1245    1245   Dollis Road
# 4  2019-02-15T17:00:00Z       20.18             1245    1245   Dollis Road
#
#   ratification_status
# 0                   P
# 1                   P
# 2                   P
# 3                   P
# 4                   P

# %%
# Get Paris air dataset 
parisair = pd.read_csv('/Users/Lenovo/Desktop/2019_A1.csv')

# %%
parisair.head()
# Out:
#    Unnamed: 0 date                       A1:CO                     A1:PM10  \
# 0           0  NaN  Autoroute A1 - Saint-Denis  Autoroute A1 - Saint-Denis
# 1           1  NaN                          A1                          A1
# 2           2  NaN         Monoxyde de carbone            PM 10 particules
# 3           3  NaN                          CO                        PM10
# 4           4  NaN                       mg/m3                   microg/m3
#
#                       A1:PM25                      A1:NO2  \
# 0  Autoroute A1 - Saint-Denis  Autoroute A1 - Saint-Denis
# 1                          A1                          A1
# 2           PM 2,5 particules             dioxyde d azote
# 3                        PM25                         NO2
# 4                   microg/m3                   microg/m3
#
#                         A1:NO                      A1:NOX
# 0  Autoroute A1 - Saint-Denis  Autoroute A1 - Saint-Denis
# 1                          A1                          A1
# 2            monoxyde d azote              oxydes d azote
# 3                          NO                         NOX
# 4                   microg/m3                   microg/m3

# %%
# Get Paris regions 
paris_regions = pd.read_csv('/Users/Lenovo/Desktop/ecoles_creches_idf.csv')

# %% [markdown]
# ### 02 - Data Cleaning/Wrangling/EDA

# %% [markdown]
# #### 02.1 - London PM 2.5 dataset

# %%
# we need only PM2.5 info from this dataset, so lets drop the other columns
londonpm25.drop(['date_UTC', 'pod_id_location','pod_id','location_name','ratification_status'], axis = 1, inplace = True)

# %%
londonpm25.describe()
# Out:
#           pm2_5_ugm3
# count  666605.000000
# mean      -67.912651
# std       272.879386
# min      -999.000000
# 25%         5.030000
# 50%         7.280000
# 75%        12.560000
# max       469.590000

# %%
# replace -999 with median  
median = float(londonpm25['pm2_5_ugm3'].median())
londonpm25["pm2_5_ugm3"] = np.where(londonpm25["pm2_5_ugm3"] == -999, median, londonpm25['pm2_5_ugm3'])

# %%
londonpm25
# Out:
#         pm2_5_ugm3
# 0            20.17
# 1            18.47
# 2            19.84
# 3            36.68
# 4            20.18
# ...            ...
# 666600        7.28
# 666601        7.28
# 666602        7.28
# 666603        7.28
# 666604        7.28
#
# [666605 rows x 1 columns]

# %%
# check for duplicates 
londonpm25.duplicated(subset=None, keep='first')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 666600     True
# 666601     True
# 666602     True
# 666603     True
# 666604     True
# Length: 666605, dtype: bool

# %%
# remove duplicates 
londonpm = londonpm25.drop_duplicates()

# %%
# check for duplicates again 
londonpm.duplicated(subset=None, keep='first')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 654908    False
# 655123    False
# 655124    False
# 655125    False
# 655128    False
# Length: 9490, dtype: bool

# %%
londonpm
# Out:
#         pm2_5_ugm3
# 0            20.17
# 1            18.47
# 2            19.84
# 3            36.68
# 4            20.18
# ...            ...
# 654908       92.01
# 655123       86.73
# 655124       88.57
# 655125       88.41
# 655128       84.36
#
# [9490 rows x 1 columns]

# %% [markdown]
# #### 02.2 - London NO2 dataset

# %%
londonno2
# Out:
#                     date_UTC  no2_ugm3  pod_id_location  pod_id  \
# 0       2019-02-15T17:00:00Z     61.99             1245    1245
# 1       2019-02-15T18:00:00Z     67.33             1245    1245
# 2       2019-02-15T19:00:00Z     72.61             1245    1245
# 3       2019-02-15T20:00:00Z     67.24             1245    1245
# 4       2019-02-15T21:00:00Z     59.78             1245    1245
# ...                      ...       ...              ...     ...
# 733825  2019-03-14T22:00:00Z     85.06           992450   99245
# 733826  2019-03-14T23:00:00Z     64.31           992450   99245
# 733827  2019-03-15T00:00:00Z     56.04           992450   99245
# 733828  2019-03-15T01:00:00Z     47.78           992450   99245
# 733829  2019-03-15T02:00:00Z     33.09           992450   99245
#
#         location_name ratification_status
# 0         Dollis Road                   P
# 1         Dollis Road                   P
# 2         Dollis Road                   P
# 3         Dollis Road                   P
# 4         Dollis Road                   P
# ...               ...                 ...
# 733825  Finchley Road                   P
# 733826  Finchley Road                   P
# 733827  Finchley Road                   P
# 733828  Finchley Road                   P
# 733829  Finchley Road                   P
#
# [733830 rows x 6 columns]

# %%
# we dont need IDs and ratification_status columns, so lets drop them 
londonno2.drop(['pod_id_location','pod_id', 'ratification_status'], axis = 1, inplace = True)

# %%
londonno2.head()
# Out:
#                date_UTC  no2_ugm3 location_name
# 0  2019-02-15T17:00:00Z     61.99   Dollis Road
# 1  2019-02-15T18:00:00Z     67.33   Dollis Road
# 2  2019-02-15T19:00:00Z     72.61   Dollis Road
# 3  2019-02-15T20:00:00Z     67.24   Dollis Road
# 4  2019-02-15T21:00:00Z     59.78   Dollis Road

# %%
londonno2
# Out:
#                     date_UTC  no2_ugm3  location_name
# 0       2019-02-15T17:00:00Z     61.99    Dollis Road
# 1       2019-02-15T18:00:00Z     67.33    Dollis Road
# 2       2019-02-15T19:00:00Z     72.61    Dollis Road
# 3       2019-02-15T20:00:00Z     67.24    Dollis Road
# 4       2019-02-15T21:00:00Z     59.78    Dollis Road
# ...                      ...       ...            ...
# 733825  2019-03-14T22:00:00Z     85.06  Finchley Road
# 733826  2019-03-14T23:00:00Z     64.31  Finchley Road
# 733827  2019-03-15T00:00:00Z     56.04  Finchley Road
# 733828  2019-03-15T01:00:00Z     47.78  Finchley Road
# 733829  2019-03-15T02:00:00Z     33.09  Finchley Road
#
# [733830 rows x 3 columns]

# %%
# check for duplicates 
londonno2.duplicated(subset=None, keep='first')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 733825    False
# 733826    False
# 733827    False
# 733828    False
# 733829    False
# Length: 733830, dtype: bool

# %%
# replace -999 with median  
median = float(londonno2['no2_ugm3'].median())
londonno2["no2_ugm3"] = np.where(londonno2["no2_ugm3"] == -999, median, londonno2['no2_ugm3'])

# %%
londonno2
# Out:
#                     date_UTC  no2_ugm3  location_name
# 0       2019-02-15T17:00:00Z     61.99    Dollis Road
# 1       2019-02-15T18:00:00Z     67.33    Dollis Road
# 2       2019-02-15T19:00:00Z     72.61    Dollis Road
# 3       2019-02-15T20:00:00Z     67.24    Dollis Road
# 4       2019-02-15T21:00:00Z     59.78    Dollis Road
# ...                      ...       ...            ...
# 733825  2019-03-14T22:00:00Z     85.06  Finchley Road
# 733826  2019-03-14T23:00:00Z     64.31  Finchley Road
# 733827  2019-03-15T00:00:00Z     56.04  Finchley Road
# 733828  2019-03-15T01:00:00Z     47.78  Finchley Road
# 733829  2019-03-15T02:00:00Z     33.09  Finchley Road
#
# [733830 rows x 3 columns]

# %%
# lets merge two dataframes 
londonair = pd.concat([londonno2, londonpm], axis=1, join="inner")

# %%
londonair
# Out:
#                     date_UTC  no2_ugm3                 location_name  \
# 0       2019-02-15T17:00:00Z     61.99                   Dollis Road
# 1       2019-02-15T18:00:00Z     67.33                   Dollis Road
# 2       2019-02-15T19:00:00Z     72.61                   Dollis Road
# 3       2019-02-15T20:00:00Z     67.24                   Dollis Road
# 4       2019-02-15T21:00:00Z     59.78                   Dollis Road
# ...                      ...       ...                           ...
# 654908  2019-01-11T16:00:00Z     66.72  National Physical Laboratory
# 655123  2019-01-20T15:00:00Z     39.52  National Physical Laboratory
# 655124  2019-01-20T16:00:00Z     36.07  National Physical Laboratory
# 655125  2019-01-20T17:00:00Z     41.86  National Physical Laboratory
# 655128  2019-01-20T20:00:00Z     90.09  National Physical Laboratory
#
#         pm2_5_ugm3
# 0            20.17
# 1            18.47
# 2            19.84
# 3            36.68
# 4            20.18
# ...            ...
# 654908       92.01
# 655123       86.73
# 655124       88.57
# 655125       88.41
# 655128       84.36
#
# [9490 rows x 4 columns]

# %%
# we have location names, but not city name itsels. So, lets ad a city name (London) to df as well. 
londonair['city'] = 'London'

# %%
londonair
# Out:
#                     date_UTC  no2_ugm3                 location_name  \
# 0       2019-02-15T17:00:00Z     61.99                   Dollis Road
# 1       2019-02-15T18:00:00Z     67.33                   Dollis Road
# 2       2019-02-15T19:00:00Z     72.61                   Dollis Road
# 3       2019-02-15T20:00:00Z     67.24                   Dollis Road
# 4       2019-02-15T21:00:00Z     59.78                   Dollis Road
# ...                      ...       ...                           ...
# 654908  2019-01-11T16:00:00Z     66.72  National Physical Laboratory
# 655123  2019-01-20T15:00:00Z     39.52  National Physical Laboratory
# 655124  2019-01-20T16:00:00Z     36.07  National Physical Laboratory
# 655125  2019-01-20T17:00:00Z     41.86  National Physical Laboratory
# 655128  2019-01-20T20:00:00Z     90.09  National Physical Laboratory
#
#         pm2_5_ugm3    city
# 0            20.17  London
# 1            18.47  London
# 2            19.84  London
# 3            36.68  London
# 4            20.18  London
# ...            ...     ...
# 654908       92.01  London
# 655123       86.73  London
# 655124       88.57  London
# 655125       88.41  London
# 655128       84.36  London
#
# [9490 rows x 5 columns]

# %%
# for readibility, lets re-order column positions: to have 'city', 'NO2' and 'PM2.5' next to each other
london = londonair[['date_UTC', 'city','no2_ugm3', 'pm2_5_ugm3','location_name']]

# %%
# lets rename column modify column names for better readibility 
london1=london.rename(columns={"date_UTC": "date", "no2_ugm3": "no2", "pm2_5_ugm3":"pm2_5"})

# %%
# reset index 
london1.reset_index(drop=True, inplace=True)

# %%
london1.head()
# Out:
#                    date    city    no2  pm2_5 location_name
# 0  2019-02-15T17:00:00Z  London  61.99  20.17   Dollis Road
# 1  2019-02-15T18:00:00Z  London  67.33  18.47   Dollis Road
# 2  2019-02-15T19:00:00Z  London  72.61  19.84   Dollis Road
# 3  2019-02-15T20:00:00Z  London  67.24  36.68   Dollis Road
# 4  2019-02-15T21:00:00Z  London  59.78  20.18   Dollis Road

# %%
# reset index per date 
london_final = london1.sort_values(by=['date'],ignore_index=True)

# %%
london_final
# Out:
#                       date    city    no2   pm2_5  \
# 0     2019-01-01T00:00:00Z  London  30.62   16.92
# 1     2019-01-01T00:00:00Z  London  30.62   88.66
# 2     2019-01-01T01:00:00Z  London  30.62   77.81
# 3     2019-01-01T01:00:00Z  London  30.62   41.67
# 4     2019-01-01T02:00:00Z  London  43.31  123.38
# ...                    ...     ...    ...     ...
# 9485  2019-12-31T20:00:00Z  London  27.66   64.73
# 9486  2019-12-31T21:00:00Z  London  14.89   33.61
# 9487  2019-12-31T21:00:00Z  London  34.28   22.79
# 9488  2019-12-31T22:00:00Z  London  12.69   33.77
# 9489  2019-12-31T22:00:00Z  London  32.99   21.13
#
#                       location_name
# 0                    Savernake Road
# 1     Triangle Adventure Playground
# 2                   Hunslett Street
# 3                     Pattison Road
# 4                 Tower Bridge Road
# ...                             ...
# 9485               West Smithsfield
# 9486                    Dollis Road
# 9487                 Savernake Road
# 9488                    Dollis Road
# 9489                 Savernake Road
#
# [9490 rows x 5 columns]

# %%
# check for dataframe 
london_final.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9490 entries, 0 to 9489
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           9490 non-null   object
#  1   city           9490 non-null   object
#  2   no2            9490 non-null   float64
#  3   pm2_5          9490 non-null   float64
#  4   location_name  9490 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 2.1 MB

# %%
# check for missing values
london_final.isna().sum()
# Out:
# date             0
# city             0
# no2              0
# pm2_5            0
# location_name    0
# dtype: int64

# %%
london_final.to_csv('/Users/Lenovo/Desktop/london_regions.csv')

# %% [markdown]
# #### 02.3 - Paris

# %%
paris_regions.head()
# Out:
#          ID                                                nom  departement  \
# 0  0750026W  L'Enseignement par petits groupes (Ecole secon...           75
# 1  0750106H  Ecole technologique privée CCIP Centre des For...           75
# 2  0750132L        Ecole primaire privée Notre-Dame-Saint Roch           75
# 3  0750136R                Ecole primaire privée Saint-Sauveur           75
# 4  0750138T   Ecole primaire privée Sainte Geneviève du Marais           75
#
#       ville     CP        type   NO2_2012   NO2_2013   NO2_2014   NO2_2015  \
# 0  Paris 15  75015  secondaire  41.316912  42.916257  40.610102  37.182711
# 1  Paris 20  75020  secondaire  63.683878  60.890328  53.322156  45.804898
# 2  Paris 01  75001    primaire  41.507336  41.598420  42.855147  39.286859
# 3  Paris 02  75002    primaire  45.197342  44.280198  45.187931  40.855468
# 4  Paris 03  75003    primaire  40.109546  39.257252  39.688121  37.249166
#
#    ...  PM10_2015  PM10_2016  PM10_2017  PM25_2012  PM25_2013  PM25_2014  \
# 0  ...  23.790138  23.077844  21.782889  17.152857  18.637080  14.895546
# 1  ...  26.063983  23.803116  23.020608  22.692531  23.629341  18.628494
# 2  ...  22.995246  22.400441  20.867075  16.614189  18.142261  14.487745
# 3  ...  23.650961  23.405547  22.650735  17.713481  19.089383  15.433904
# 4  ...  22.808231  22.049934  20.717201  16.332941  17.645253  14.270936
#
#    PM25_2015  PM25_2016  PM25_2017                               geometry
# 0  15.277787  14.806532  13.549347   c(2.2908106734441, 48.8421565600018)
# 1  16.978740  15.434943  14.429643  c(2.40580700033425, 48.8756657433978)
# 2  14.562495  14.134427  12.561472  c(2.33270615799049, 48.8661396641722)
# 3  15.067306  14.756645  15.118740  c(2.34734689771536, 48.8668886093452)
# 4  14.391215  13.911639  12.654443  c(2.36480092620121, 48.8569700986785)
#
# [5 rows x 25 columns]

# %%
pr = paris_regions[['nom']]

# %%
pr
# Out:
#                                                      nom
# 0      L'Enseignement par petits groupes (Ecole secon...
# 1      Ecole technologique privée CCIP Centre des For...
# 2            Ecole primaire privée Notre-Dame-Saint Roch
# 3                    Ecole primaire privée Saint-Sauveur
# 4       Ecole primaire privée Sainte Geneviève du Marais
# ...                                                  ...
# 12525                              Les p tits Cressonets
# 12526                                       Les lucioles
# 12527                                    Les coccinelles
# 12528                                              Soyer
# 12529                                     Emile Bergerat
#
# [12530 rows x 1 columns]

# %%
# lets follow the same steps for paris air dataset.t
parisair.head()
# Out:
#    Unnamed: 0 date                       A1:CO                     A1:PM10  \
# 0           0  NaN  Autoroute A1 - Saint-Denis  Autoroute A1 - Saint-Denis
# 1           1  NaN                          A1                          A1
# 2           2  NaN         Monoxyde de carbone            PM 10 particules
# 3           3  NaN                          CO                        PM10
# 4           4  NaN                       mg/m3                   microg/m3
#
#                       A1:PM25                      A1:NO2  \
# 0  Autoroute A1 - Saint-Denis  Autoroute A1 - Saint-Denis
# 1                          A1                          A1
# 2           PM 2,5 particules             dioxyde d azote
# 3                        PM25                         NO2
# 4                   microg/m3                   microg/m3
#
#                         A1:NO                      A1:NOX
# 0  Autoroute A1 - Saint-Denis  Autoroute A1 - Saint-Denis
# 1                          A1                          A1
# 2            monoxyde d azote              oxydes d azote
# 3                          NO                         NOX
# 4                   microg/m3                   microg/m3

# %%
# lets merge two dataframes 
parisair = pd.concat([parisair, pr], axis=1, join="inner")

# %%
parisair
# Out:
#       Unnamed: 0                  date                       A1:CO  \
# 0              0                   NaN  Autoroute A1 - Saint-Denis
# 1              1                   NaN                          A1
# 2              2                   NaN         Monoxyde de carbone
# 3              3                   NaN                          CO
# 4              4                   NaN                       mg/m3
# ...          ...                   ...                         ...
# 8760        8760  2019-12-31 20:00:00Z                       0.915
# 8761        8761  2019-12-31 21:00:00Z                       1.233
# 8762        8762  2019-12-31 22:00:00Z                       1.588
# 8763        8763  2019-12-31 23:00:00Z                       1.503
# 8764        8764  2020-01-01 00:00:00Z                       0.983
#
#                          A1:PM10                     A1:PM25  \
# 0     Autoroute A1 - Saint-Denis  Autoroute A1 - Saint-Denis
# 1                             A1                          A1
# 2               PM 10 particules           PM 2,5 particules
# 3                           PM10                        PM25
# 4                      microg/m3                   microg/m3
# ...                          ...                         ...
# 8760                        85.4                        57.2
# 8761                        98.8                        65.6
# 8762                       117.9                        85.5
# 8763                       113.1                        86.8
# 8764                       114.6                        87.2
#
#                           A1:NO2                       A1:NO  \
# 0     Autoroute A1 - Saint-Denis  Autoroute A1 - Saint-Denis
# 1                             A1                          A1
# 2                dioxyde d azote            monoxyde d azote
# 3                            NO2                          NO
# 4                      microg/m3                   microg/m3
# ...                          ...                         ...
# 8760                        81.3                       255.8
# 8761                       102.3                       336.4
# 8762                       112.8                         395
# 8763                        94.7                       322.6
# 8764                        66.9                       196.3
#
#                           A1:NOX  \
# 0     Autoroute A1 - Saint-Denis
# 1                             A1
# 2                 oxydes d azote
# 3                            NOX
# 4                      microg/m3
# ...                          ...
# 8760                       474.1
# 8761                       618.7
# 8762                       718.9
# 8763                       589.3
# 8764                       368.2
#
#                                                     nom
# 0     L'Enseignement par petits groupes (Ecole secon...
# 1     Ecole technologique privée CCIP Centre des For...
# 2           Ecole primaire privée Notre-Dame-Saint Roch
# 3                   Ecole primaire privée Saint-Sauveur
# 4      Ecole primaire privée Sainte Geneviève du Marais
# ...                                                 ...
# 8760                    Ecole primaire Henri Barbusse B
# 8761                       Ecole maternelle Chantefleur
# 8762                       Ecole élémentaire Anne Frank
# 8763                     Ecole primaire Gustave Loiseau
# 8764                          Ecole primaire Emile Zola
#
# [8765 rows x 9 columns]

# %%
# remove column 'Unnamed'
parisair = parisair.loc[:, ~parisair.columns.str.contains('^Unnamed')]

# %%
parisair
# Out:
#                       date                       A1:CO  \
# 0                      NaN  Autoroute A1 - Saint-Denis
# 1                      NaN                          A1
# 2                      NaN         Monoxyde de carbone
# 3                      NaN                          CO
# 4                      NaN                       mg/m3
# ...                    ...                         ...
# 8760  2019-12-31 20:00:00Z                       0.915
# 8761  2019-12-31 21:00:00Z                       1.233
# 8762  2019-12-31 22:00:00Z                       1.588
# 8763  2019-12-31 23:00:00Z                       1.503
# 8764  2020-01-01 00:00:00Z                       0.983
#
#                          A1:PM10                     A1:PM25  \
# 0     Autoroute A1 - Saint-Denis  Autoroute A1 - Saint-Denis
# 1                             A1                          A1
# 2               PM 10 particules           PM 2,5 particules
# 3                           PM10                        PM25
# 4                      microg/m3                   microg/m3
# ...                          ...                         ...
# 8760                        85.4                        57.2
# 8761                        98.8                        65.6
# 8762                       117.9                        85.5
# 8763                       113.1                        86.8
# 8764                       114.6                        87.2
#
#                           A1:NO2                       A1:NO  \
# 0     Autoroute A1 - Saint-Denis  Autoroute A1 - Saint-Denis
# 1                             A1                          A1
# 2                dioxyde d azote            monoxyde d azote
# 3                            NO2                          NO
# 4                      microg/m3                   microg/m3
# ...                          ...                         ...
# 8760                        81.3                       255.8
# 8761                       102.3                       336.4
# 8762                       112.8                         395
# 8763                        94.7                       322.6
# 8764                        66.9                       196.3
#
#                           A1:NOX  \
# 0     Autoroute A1 - Saint-Denis
# 1                             A1
# 2                 oxydes d azote
# 3                            NOX
# 4                      microg/m3
# ...                          ...
# 8760                       474.1
# 8761                       618.7
# 8762                       718.9
# 8763                       589.3
# 8764                       368.2
#
#                                                     nom
# 0     L'Enseignement par petits groupes (Ecole secon...
# 1     Ecole technologique privée CCIP Centre des For...
# 2           Ecole primaire privée Notre-Dame-Saint Roch
# 3                   Ecole primaire privée Saint-Sauveur
# 4      Ecole primaire privée Sainte Geneviève du Marais
# ...                                                 ...
# 8760                    Ecole primaire Henri Barbusse B
# 8761                       Ecole maternelle Chantefleur
# 8762                       Ecole élémentaire Anne Frank
# 8763                     Ecole primaire Gustave Loiseau
# 8764                          Ecole primaire Emile Zola
#
# [8765 rows x 8 columns]

# %%
# lower and replace
parisair.columns=[e.lower().replace(' ', '_') for e in parisair.columns]   
parisair.columns
# Out:
# Index(['date', 'a1:co', 'a1:pm10', 'a1:pm25', 'a1:no2', 'a1:no', 'a1:nox',
#        'nom'],
#       dtype='object')

# %%
# drop columns
parisair.drop(['a1:co', 'a1:pm10', 'a1:no', 'a1:nox'], axis = 1, inplace = True)
# Out:
# C:\Users\Lenovo\anaconda3\envs\excondables\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# add city column 
parisair['city'] = 'Paris'
# Out:
# <ipython-input-47-440658a02335>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parisair['city'] = 'Paris'

# %%
parisair
# Out:
#                       date                     a1:pm25  \
# 0                      NaN  Autoroute A1 - Saint-Denis
# 1                      NaN                          A1
# 2                      NaN           PM 2,5 particules
# 3                      NaN                        PM25
# 4                      NaN                   microg/m3
# ...                    ...                         ...
# 8760  2019-12-31 20:00:00Z                        57.2
# 8761  2019-12-31 21:00:00Z                        65.6
# 8762  2019-12-31 22:00:00Z                        85.5
# 8763  2019-12-31 23:00:00Z                        86.8
# 8764  2020-01-01 00:00:00Z                        87.2
#
#                           a1:no2  \
# 0     Autoroute A1 - Saint-Denis
# 1                             A1
# 2                dioxyde d azote
# 3                            NO2
# 4                      microg/m3
# ...                          ...
# 8760                        81.3
# 8761                       102.3
# 8762                       112.8
# 8763                        94.7
# 8764                        66.9
#
#                                                     nom   city
# 0     L'Enseignement par petits groupes (Ecole secon...  Paris
# 1     Ecole technologique privée CCIP Centre des For...  Paris
# 2           Ecole primaire privée Notre-Dame-Saint Roch  Paris
# 3                   Ecole primaire privée Saint-Sauveur  Paris
# 4      Ecole primaire privée Sainte Geneviève du Marais  Paris
# ...                                                 ...    ...
# 8760                    Ecole primaire Henri Barbusse B  Paris
# 8761                       Ecole maternelle Chantefleur  Paris
# 8762                       Ecole élémentaire Anne Frank  Paris
# 8763                     Ecole primaire Gustave Loiseau  Paris
# 8764                          Ecole primaire Emile Zola  Paris
#
# [8765 rows x 5 columns]

# %%
# rename columns 
paris_updated = parisair.rename(columns={"a1:pm25":"pm2_5", "a1:no2":"no2", 'nom':'location_name'})

# %%
paris_updated
# Out:
#                       date                       pm2_5  \
# 0                      NaN  Autoroute A1 - Saint-Denis
# 1                      NaN                          A1
# 2                      NaN           PM 2,5 particules
# 3                      NaN                        PM25
# 4                      NaN                   microg/m3
# ...                    ...                         ...
# 8760  2019-12-31 20:00:00Z                        57.2
# 8761  2019-12-31 21:00:00Z                        65.6
# 8762  2019-12-31 22:00:00Z                        85.5
# 8763  2019-12-31 23:00:00Z                        86.8
# 8764  2020-01-01 00:00:00Z                        87.2
#
#                              no2  \
# 0     Autoroute A1 - Saint-Denis
# 1                             A1
# 2                dioxyde d azote
# 3                            NO2
# 4                      microg/m3
# ...                          ...
# 8760                        81.3
# 8761                       102.3
# 8762                       112.8
# 8763                        94.7
# 8764                        66.9
#
#                                           location_name   city
# 0     L'Enseignement par petits groupes (Ecole secon...  Paris
# 1     Ecole technologique privée CCIP Centre des For...  Paris
# 2           Ecole primaire privée Notre-Dame-Saint Roch  Paris
# 3                   Ecole primaire privée Saint-Sauveur  Paris
# 4      Ecole primaire privée Sainte Geneviève du Marais  Paris
# ...                                                 ...    ...
# 8760                    Ecole primaire Henri Barbusse B  Paris
# 8761                       Ecole maternelle Chantefleur  Paris
# 8762                       Ecole élémentaire Anne Frank  Paris
# 8763                     Ecole primaire Gustave Loiseau  Paris
# 8764                          Ecole primaire Emile Zola  Paris
#
# [8765 rows x 5 columns]

# %%
# drop first 5 rows
paris1 = paris_updated.drop([0, 1, 2, 3, 4])

# %%
# reset index 
paris1.reset_index(drop=True, inplace=True)

# %%
# re-order column positions
paris = paris1[['date', 'city','no2', 'pm2_5', 'location_name']]

# %%
paris
# Out:
#                       date   city    no2 pm2_5  \
# 0     2019-01-01 01:00:00Z  Paris   79.4  25.1
# 1     2019-01-01 02:00:00Z  Paris   75.1  14.7
# 2     2019-01-01 03:00:00Z  Paris  110.5  21.9
# 3     2019-01-01 04:00:00Z  Paris  111.4  24.5
# 4     2019-01-01 05:00:00Z  Paris  114.2  20.1
# ...                    ...    ...    ...   ...
# 8755  2019-12-31 20:00:00Z  Paris   81.3  57.2
# 8756  2019-12-31 21:00:00Z  Paris  102.3  65.6
# 8757  2019-12-31 22:00:00Z  Paris  112.8  85.5
# 8758  2019-12-31 23:00:00Z  Paris   94.7  86.8
# 8759  2020-01-01 00:00:00Z  Paris   66.9  87.2
#
#                                       location_name
# 0                   Ecole primaire privée Massillon
# 1          Ecole primaire privée Saint Jean Gabriel
# 2     Ecole élémentaire privée Les Francs Bourgeois
# 3                       Ecole primaire privée Sinaï
# 4            Ecole primaire privée Sainte Catherine
# ...                                             ...
# 8755                Ecole primaire Henri Barbusse B
# 8756                   Ecole maternelle Chantefleur
# 8757                   Ecole élémentaire Anne Frank
# 8758                 Ecole primaire Gustave Loiseau
# 8759                      Ecole primaire Emile Zola
#
# [8760 rows x 5 columns]

# %%
paris.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           8760 non-null   object
#  1   city           8760 non-null   object
#  2   no2            8576 non-null   object
#  3   pm2_5          8582 non-null   object
#  4   location_name  8580 non-null   object
# dtypes: object(5)
# memory usage: 3.0 MB

# %%
# check for missing values
paris.isnull().sum()
# Out:
# date               0
# city               0
# no2              184
# pm2_5            178
# location_name    180
# dtype: int64

# %%
# check for nulls 
paris_clean = paris.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
# check for nulls again 
paris_clean.isnull().sum()
# Out:
# date             0
# city             0
# no2              0
# pm2_5            0
# location_name    0
# dtype: int64

# %%
# reset index per date 
paris_final = paris_clean.sort_values(by=['date'],ignore_index=True)

# %%
paris_final
# Out:
#                       date   city    no2 pm2_5  \
# 0     2019-01-01 01:00:00Z  Paris   79.4  25.1
# 1     2019-01-01 02:00:00Z  Paris   75.1  14.7
# 2     2019-01-01 03:00:00Z  Paris  110.5  21.9
# 3     2019-01-01 04:00:00Z  Paris  111.4  24.5
# 4     2019-01-01 05:00:00Z  Paris  114.2  20.1
# ...                    ...    ...    ...   ...
# 8343  2019-12-31 20:00:00Z  Paris   81.3  57.2
# 8344  2019-12-31 21:00:00Z  Paris  102.3  65.6
# 8345  2019-12-31 22:00:00Z  Paris  112.8  85.5
# 8346  2019-12-31 23:00:00Z  Paris   94.7  86.8
# 8347  2020-01-01 00:00:00Z  Paris   66.9  87.2
#
#                                       location_name
# 0                   Ecole primaire privée Massillon
# 1          Ecole primaire privée Saint Jean Gabriel
# 2     Ecole élémentaire privée Les Francs Bourgeois
# 3                       Ecole primaire privée Sinaï
# 4            Ecole primaire privée Sainte Catherine
# ...                                             ...
# 8343                Ecole primaire Henri Barbusse B
# 8344                   Ecole maternelle Chantefleur
# 8345                   Ecole élémentaire Anne Frank
# 8346                 Ecole primaire Gustave Loiseau
# 8347                      Ecole primaire Emile Zola
#
# [8348 rows x 5 columns]

# %%
# lets merge two dataframes 
london_paris=pd.concat([london_final,paris_final],axis=0)

# %%
# reset index after merging
london_paris.reset_index(drop=True, inplace=True)

# %%
london_paris
# Out:
#                        date    city    no2   pm2_5  \
# 0      2019-01-01T00:00:00Z  London  30.62   16.92
# 1      2019-01-01T00:00:00Z  London  30.62   88.66
# 2      2019-01-01T01:00:00Z  London  30.62   77.81
# 3      2019-01-01T01:00:00Z  London  30.62   41.67
# 4      2019-01-01T02:00:00Z  London  43.31  123.38
# ...                     ...     ...    ...     ...
# 17833  2019-12-31 20:00:00Z   Paris   81.3    57.2
# 17834  2019-12-31 21:00:00Z   Paris  102.3    65.6
# 17835  2019-12-31 22:00:00Z   Paris  112.8    85.5
# 17836  2019-12-31 23:00:00Z   Paris   94.7    86.8
# 17837  2020-01-01 00:00:00Z   Paris   66.9    87.2
#
#                          location_name
# 0                       Savernake Road
# 1        Triangle Adventure Playground
# 2                      Hunslett Street
# 3                        Pattison Road
# 4                    Tower Bridge Road
# ...                                ...
# 17833  Ecole primaire Henri Barbusse B
# 17834     Ecole maternelle Chantefleur
# 17835     Ecole élémentaire Anne Frank
# 17836   Ecole primaire Gustave Loiseau
# 17837        Ecole primaire Emile Zola
#
# [17838 rows x 5 columns]

# %%
london_paris.to_csv('/Users/Lenovo/Desktop/london_paris_final.csv')
